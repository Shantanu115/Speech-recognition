# %% [markdown]
# # Vaahan.ai ASR assignment
# Deepgram Nova-2 (baseline) | Whisper Medium | IndicWhisper | Sarvam AI
# Metrics: WER, CER, Entity Hit Rate, Fuzzy Score, Latency
# Data: 20 self-recorded Bangalore locality utterances + FLEURS Hindi (30 samples, 50% noise-augmented)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q deepgram-sdk==3.* openai-whisper transformers datasets \
    jiwer rapidfuzz audiomentations soundfile librosa indic-transliteration \
    matplotlib seaborn requests tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 18.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.1/153.1 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.9/162.9 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.1 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
import os, time, warnings, unicodedata, tempfile, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import soundfile as sf
import librosa
import requests
from tqdm import tqdm
from jiwer import wer, cer
from rapidfuzz import fuzz
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate
from google.colab import userdata

warnings.filterwarnings('ignore')

DEEPGRAM_KEY   = userdata.get('DEEPGRAM_API_KEY')
SARVAM_KEY     = userdata.get('SARVAM_API_KEY')
RECORDINGS_DIR = '/content/drive/MyDrive/asr'
GROUND_TRUTH   = '/content/drive/MyDrive/asr/ground_truth.csv'
TEMP_DIR       = '/tmp/asr_eval'
os.makedirs(TEMP_DIR, exist_ok=True)

# %%
gt = pd.read_csv(GROUND_TRUTH)
gt['filename']     = gt['filename'].str.strip()
gt['ground_truth'] = gt['ground_truth'].str.strip().str.lower()
gt['locality']     = gt['locality'].str.strip()
print(len(gt), 'samples loaded')
gt.head()
# Out:
# 20 samples loaded
#               filename                                       ground_truth  \
# 0      Koramangala.mp3         haan bhai main koramangala mein rehta hoon
# 1      Indiranagar.mp3  mera ghar indiranagar ke paas hai 100 feet roa...
# 2       Whitefield.mp3         sir main whitefield se hoon thoda door hai
# 3  Electronic City.mp3  electronic city mein kaam karta hoon phase 2 mein
# 4     Marathahalli.mp3           arey marathahalli toh bohot far hai yaar
#
#           locality
# 0      Koramangala
# 1      Indiranagar
# 2       Whitefield
# 3  Electronic City
# 4     Marathahalli

# %%
FUZZY_THRESHOLD = 75

def _has_devanagari(text):
    return any('DEVANAGARI' in unicodedata.name(c, '') for c in text if c.strip())

def _normalize_word(w):
    if _has_devanagari(w):
        return transliterate(w, sanscript.DEVANAGARI, sanscript.ITRANS).lower()
    return w.lower()

def normalize(text):
    # Word-level ITRANS transliteration to handle mixed-script Hinglish output
    return ' '.join(_normalize_word(w) for w in text.strip().split()) if text else ''

def score(ref, locality, raw):
    hyp     = normalize(raw)
    fscore  = fuzz.partial_ratio(locality.lower(), hyp.lower())
    return {
        'hypothesis_raw': raw,
        'hypothesis':     hyp,
        'wer':            _safe_wer(ref, hyp),
        'cer':            _safe_cer(ref, hyp),
        'fuzzy_score':    fscore,
        'entity_hit':     int(fscore >= FUZZY_THRESHOLD),
    }

def _safe_wer(ref, hyp):
    try:    return wer(ref, hyp)
    except: return 1.0

def _safe_cer(ref, hyp):
    try:    return cer(ref, hyp)
    except: return 1.0

def audio_path(filename):
    return os.path.join(RECORDINGS_DIR, filename)

def load_audio(path, sr=16000):
    return librosa.load(path, sr=sr, mono=True)

def to_wav(audio, sr=16000):
    tmp = tempfile.NamedTemporaryFile(suffix='.wav', delete=False)
    sf.write(tmp.name, audio, sr)
    return tmp.name

def cleanup(path):
    if path and os.path.exists(path):
        os.unlink(path)

# %% [markdown]
# ## 1. Deepgram Nova-2 (Baseline)

# %%
from deepgram import DeepgramClient, PrerecordedOptions

def run_deepgram(df, api_key, base_dir=None):
    client  = DeepgramClient(api_key)
    opts    = PrerecordedOptions(model='nova-2', language='hi', smart_format=True)
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc='Deepgram'):
        path = os.path.join(base_dir or RECORDINGS_DIR, row['filename'])
        tmp  = None
        try:
            audio, sr = load_audio(path)
            tmp = to_wav(audio, sr)
            with open(tmp, 'rb') as f:
                t0  = time.time()
                res = client.listen.rest.v('1').transcribe_file({'buffer': f.read()}, opts)
                lat = time.time() - t0
            raw = res.results.channels[0].alternatives[0].transcript
        except Exception as e:
            print(f'  [{row["filename"]}] {e}')
            raw, lat = '', None
        finally:
            cleanup(tmp)
        results.append({'filename': row['filename'], 'locality': row['locality'],
                        'ground_truth': row['ground_truth'], 'latency_s': lat,
                        'model': 'Deepgram Nova-2', **score(row['ground_truth'], row['locality'], raw)})
    return pd.DataFrame(results)

deepgram_df = run_deepgram(gt, DEEPGRAM_KEY)
print(f"WER {deepgram_df['wer'].mean():.3f}  CER {deepgram_df['cer'].mean():.3f}  "
      f"Fuzzy {deepgram_df['fuzzy_score'].mean():.1f}  EHR {deepgram_df['entity_hit'].mean():.1%}  "
      f"Latency {deepgram_df['latency_s'].mean():.2f}s")
deepgram_df[['locality','ground_truth','hypothesis_raw','hypothesis','wer','fuzzy_score','entity_hit']]
# Out:
# Deepgram: 100%|██████████| 20/20 [01:10<00:00,  3.52s/it]
# WER 0.831  CER 0.399  Fuzzy 69.5  EHR 55.0%  Latency 1.65s
#                locality                                       ground_truth  \
# 0           Koramangala         haan bhai main koramangala mein rehta hoon
# 1           Indiranagar  mera ghar indiranagar ke paas hai 100 feet roa...
# 2            Whitefield         sir main whitefield se hoon thoda door hai
# 3       Electronic City  electronic city mein kaam karta hoon phase 2 mein
# 4          Marathahalli           arey marathahalli toh bohot far hai yaar
# 5             Jayanagar           main jayanagar 4th block mein rehta hoon
# 6           Rajajinagar                haan rajajinagar wahan se hoon main
# 7                Hebbal               hebbal flyover ke paas mera ghar hai
# 8             Yelahanka  main yelahanka new town mein shift hua hoon re...
# 9            HSR Layout                hsr layout sector 2 mein rehta hoon
# 10           BTM Layout                     btm layout haan 2nd stage mein
# 11           Silk Board          office silk board junction ke paas hi hai
# 12            Bellandur                 bellandur mein flat liya hai maine
# 13             Sarjapur                    sarjapur road pe rehte hain hum
# 14               Peenya           peenya industrial area mein job hai meri
# 15  Rajarajeshwarinagar  rajarajeshwarinagar mein rehta hoon main rr na...
# 16             KR Puram        kr puram bridge ke paas drop kar dena mujhe
# 17         Banashankari             banashankari temple ke paas rehta hoon
# 18         Yeshwanthpur           yeshwanthpur station ke paas mera pg hai
# 19          Thanisandra                 thanisandra main road pe hoon abhi
#
#                                        hypothesis_raw  \
# 0                 हां भाई, मैं कुरमंगला में रहता हूं.
# 1
# 2            Sir मैं wife field से हूं. थोड़ा दूध है.
# 3           Electricity में काम करता हूं phase 2 में.
# 4                   अरे मारा थाली तो बहुत far है यार.
# 5                मैं जयनगर fourth block में रहता हूं.
# 6                          हां, नगर. वहां से हूं मैं.
# 7                  यह बाल fiber के पास मिला करते हैं.
# 8       मैं यह लहंका new town में shift हूं recently.
# 9          पीछे साथ लिया और sector 2 में रहता हूं मैं
# 10                  B team layout? हां, second stage.
# 11               Office सिल्क board जंक्शन के पास है.
# 12                Balance दूर में flat लिया है मैंने.
# 13                       सरजापुर road पर रहते हैं हम.
# 14            पीनीया industrial area में job है मेरी.
# 15  राजा राजेश्वरी नगर में रहता हूं मैं आरा नगर बो...
# 16        केरपुरम bridge के पास drop कर देना है मुझे.
# 17                   वन शंकरी temple के पास रहता हूं.
# 18            जैसलमेरपुर station के पास मेरा busy है.
# 19                              Main road पर हूं अभी.
#
#                                            hypothesis       wer  fuzzy_score  \
# 0          ham bhai, maim kuramamgala mem rahata hum.  1.000000    81.818182
# 1                                                      1.000000     0.000000
# 2       sir maim wife field se hum. tho.da dudha hai.  0.875000    80.000000
# 3        electricity mem kama karata hum phase 2 mem.  0.777778    84.615385
# 4              are mara thali to bahuta far hai yara.  0.857143    75.000000
# 5        maim jayanagara fourth block mem rahata hum.  0.857143   100.000000
# 6                     ham, nagara. vaham se hum maim.  0.833333    57.142857
# 7           yaha bala fiber ke pasa mila karate haim.  1.000000    66.666667
# 8   maim yaha lahamka new town mem shift hum recen...  0.777778    66.666667
# 9   piche satha liya aura sector 2 mem rahata hum ...  1.142857    50.000000
# 10                  b team layout? ham, second stage.  1.000000    80.000000
# 11          office silka board jamkshana ke pasa hai.  0.625000    90.000000
# 12             balance dura mem flat liya hai maimne.  0.666667    66.666667
# 13             sarajapura road para rahate haim hama.  0.833333    87.500000
# 14           piniya industrial area mem job hai meri.  0.428571    66.666667
# 15  raja rajeshvari nagara mem rahata hum maim ara...  1.200000    84.210526
# 16  kerapurama bridge ke pasa drop kara dena hai m...  0.666667    75.000000
# 17           vana shamkari temple ke pasa rahata hum.  0.833333    83.333333
# 18     jaisalamerapura station ke pasa mera busy hai.  0.571429    41.666667
# 19                           main road para hum abhi.  0.666667    52.631579
#
#     entity_hit
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# 5            1
# 6            0
# 7            0
# 8            0
# 9            0
# 10           1
# 11           1
# 12           0
# 13           1
# 14           0
# 15           1
# 16           1
# 17           1
# 18           0
# 19           0

# %% [markdown]
# ## 2. Whisper Medium

# %%
import whisper

whisper_model = whisper.load_model('medium')

def run_whisper(df, model, label='Whisper Medium', base_dir=None):
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc=label):
        path = os.path.join(base_dir or RECORDINGS_DIR, row['filename'])
        try:
            t0  = time.time()
            out = model.transcribe(path, language='hi', fp16=True)
            lat = time.time() - t0
            raw = out['text']
        except Exception as e:
            print(f'  [{row["filename"]}] {e}')
            raw, lat = '', None
        results.append({'filename': row['filename'], 'locality': row['locality'],
                        'ground_truth': row['ground_truth'], 'latency_s': lat,
                        'model': label, **score(row['ground_truth'], row['locality'], raw)})
    return pd.DataFrame(results)

whisper_df = run_whisper(gt, whisper_model)
print(f"WER {whisper_df['wer'].mean():.3f}  CER {whisper_df['cer'].mean():.3f}  "
      f"Fuzzy {whisper_df['fuzzy_score'].mean():.1f}  EHR {whisper_df['entity_hit'].mean():.1%}  "
      f"Latency {whisper_df['latency_s'].mean():.2f}s")
whisper_df[['locality','ground_truth','hypothesis_raw','hypothesis','wer','fuzzy_score','entity_hit']]
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:12<00:00, 118MiB/s]
# Whisper Medium: 100%|██████████| 20/20 [00:41<00:00,  2.07s/it]
# WER 0.861  CER 0.410  Fuzzy 77.1  EHR 60.0%  Latency 2.06s
#                locality                                       ground_truth  \
# 0           Koramangala         haan bhai main koramangala mein rehta hoon
# 1           Indiranagar  mera ghar indiranagar ke paas hai 100 feet roa...
# 2            Whitefield         sir main whitefield se hoon thoda door hai
# 3       Electronic City  electronic city mein kaam karta hoon phase 2 mein
# 4          Marathahalli           arey marathahalli toh bohot far hai yaar
# 5             Jayanagar           main jayanagar 4th block mein rehta hoon
# 6           Rajajinagar                haan rajajinagar wahan se hoon main
# 7                Hebbal               hebbal flyover ke paas mera ghar hai
# 8             Yelahanka  main yelahanka new town mein shift hua hoon re...
# 9            HSR Layout                hsr layout sector 2 mein rehta hoon
# 10           BTM Layout                     btm layout haan 2nd stage mein
# 11           Silk Board          office silk board junction ke paas hi hai
# 12            Bellandur                 bellandur mein flat liya hai maine
# 13             Sarjapur                    sarjapur road pe rehte hain hum
# 14               Peenya           peenya industrial area mein job hai meri
# 15  Rajarajeshwarinagar  rajarajeshwarinagar mein rehta hoon main rr na...
# 16             KR Puram        kr puram bridge ke paas drop kar dena mujhe
# 17         Banashankari             banashankari temple ke paas rehta hoon
# 18         Yeshwanthpur           yeshwanthpur station ke paas mera pg hai
# 19          Thanisandra                 thanisandra main road pe hoon abhi
#
#                                        hypothesis_raw  \
# 0                   हा बही मैं कुर्मंग्रा में रहा हूँ
# 1         मेरा गर इंजरानगर के पाज से सौफिट रोड के उपर
# 2                 सदमा वाय फेल से हूं थोले दो रहे हैं
# 3         एलेक्टॉरिज़िटिय में काम परता हूं फेज टू में
# 4                      अरे मारा थली तो बोट फार है यार
# 5                  मैं जैनगर फौर्त ब्लॉफ में रहता हूं
# 6                           हा रारालीनगर वहां से मुइं
# 7              एब भाल्था यवर्के पास्मी राज वर्के हैं।
# 8    मैं येलहंका नूर टान में शिफ्ट हूँ हूँ रीसेंगलीं।
# 9      H.S.S.S.R.B layout sector 2 में रहता हूँ नहीं।
# 10                        BTM layout हाँ Second stage
# 11               office silk board junction के पास है
# 12                  बेलन दूर में फ्लाट लिया है मैं ने
# 13                        सर्जापुर रोट पे रेते हैं हम
# 14          पीन्या इंड़र्स्टल एरिया में जब है में जी।
# 15   राजा राज़शवरी नगर में रहता हु में आहरा नगर बो...
# 16         के आर पूरम ब्रिज के पास ट्रॉप कर देना मुझे
# 17                   बनशंकरी टिमप्रिल के पास रहता हूं
# 18             जेश्वन्पुर्ष्टेशन के पास मेरा पीजी हैं
# 19                     आनी सांड्रा में रोट पे हूँ अभी
#
#                                            hypothesis       wer  fuzzy_score  \
# 0                ha bahi maim kurmamgra mem raha hu.n  1.000000    54.545455
# 1   mera gara imjaranagara ke paja se sauphita rod...  0.727273    72.727273
# 2         sadama vaya phela se hum thole do rahe haim  1.000000    35.294118
# 3    elektaॉrizitiya mem kama parata hum pheja tu mem  1.000000    62.068966
# 4               are mara thali to bota phara hai yara  1.000000    75.000000
# 5       maim jainagara phaurta blaॉpha mem rahata hum  1.000000    77.777778
# 6                       ha raralinagara vaham se muim  0.833333    81.818182
# 7          eba bhaltha yavarke pasmi raja varke haim|  1.000000    66.666667
# 8   maim yelahamka nura tana mem shiphta hu.n hu.n...  1.000000    88.888889
# 9   h.s.s.s.r.b layout sector 2 mem rahata hu.n na...  0.714286    80.000000
# 10                       btm layout ha.n second stage  0.500000   100.000000
# 11             office silk board junction ke pasa hai  0.250000   100.000000
# 12            belana dura mem phlata liya hai maim ne  1.000000    77.777778
# 13                   sarjapura rota pe rete haim hama  0.833333   100.000000
# 14       pinya im.darstala eriya mem jaba hai mem ji|  1.000000    72.727273
# 15  raja razashavari nagara mem rahata hu mem ahar...  1.200000    68.421053
# 16  ke ara purama brija ke pasa traॉpa kara dena m...  0.777778    87.500000
# 17          banashamkari timaprila ke pasa rahata hum  0.833333    91.666667
# 18         jeshvanpurshteshana ke pasa mera piji haim  0.714286    72.727273
# 19                   ani samdra mem rota pe hu.n abhi  0.833333    76.190476
#
#     entity_hit
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# 5            1
# 6            1
# 7            0
# 8            1
# 9            1
# 10           1
# 11           1
# 12           1
# 13           1
# 14           0
# 15           0
# 16           1
# 17           1
# 18           0
# 19           1

# %% [markdown]
# ## 3. IndicWhisper (Hindi fine-tuned)

# %%
from transformers import pipeline as hf_pipeline
import torch

device     = 0 if torch.cuda.is_available() else -1
dtype      = torch.float16 if device == 0 else torch.float32
indic_pipe = hf_pipeline('automatic-speech-recognition',
                          model='vasista22/whisper-hindi-large-v2',
                          device=device, dtype=dtype, chunk_length_s=30)

def run_indicwhisper(df, pipe, label='IndicWhisper', base_dir=None):
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc=label):
        path = os.path.join(base_dir or RECORDINGS_DIR, row['filename'])
        try:
            audio, sr = load_audio(path)
            t0  = time.time()
            out = pipe({'array': audio, 'sampling_rate': sr})
            lat = time.time() - t0
            raw = out['text']
        except Exception as e:
            print(f'  [{row["filename"]}] {e}')
            raw, lat = '', None
        results.append({'filename': row['filename'], 'locality': row['locality'],
                        'ground_truth': row['ground_truth'], 'latency_s': lat,
                        'model': label, **score(row['ground_truth'], row['locality'], raw)})
    return pd.DataFrame(results)

indic_df = run_indicwhisper(gt, indic_pipe)
print(f"WER {indic_df['wer'].mean():.3f}  CER {indic_df['cer'].mean():.3f}  "
      f"Fuzzy {indic_df['fuzzy_score'].mean():.1f}  EHR {indic_df['entity_hit'].mean():.1%}  "
      f"Latency {indic_df['latency_s'].mean():.2f}s")
indic_df[['locality','ground_truth','hypothesis_raw','hypothesis','wer','fuzzy_score','entity_hit']]
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/1259 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/300 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/832 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
#
# IndicWhisper:   0%|          | 0/20 [00:00<?, ?it/s]A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
#
# IndicWhisper:   5%|▌         | 1/20 [00:10<03:23, 10.69s/it]
# IndicWhisper:  10%|█         | 2/20 [00:19<02:48,  9.38s/it]
# IndicWhisper:  15%|█▌        | 3/20 [00:27<02:30,  8.88s/it]
# IndicWhisper:  20%|██        | 4/20 [00:34<02:12,  8.29s/it]
# IndicWhisper:  25%|██▌       | 5/20 [00:40<01:47,  7.17s/it]
# IndicWhisper:  30%|███       | 6/20 [00:46<01:36,  6.86s/it]
# IndicWhisper:  35%|███▌      | 7/20 [00:51<01:22,  6.37s/it]
# IndicWhisper:  40%|████      | 8/20 [00:57<01:14,  6.24s/it]
# IndicWhisper:  45%|████▌     | 9/20 [01:07<01:19,  7.23s/it]
# IndicWhisper:  50%|█████     | 10/20 [01:15<01:14,  7.47s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#
# IndicWhisper:  55%|█████▌    | 11/20 [01:21<01:05,  7.28s/it]
# IndicWhisper:  60%|██████    | 12/20 [01:27<00:55,  6.90s/it]
# IndicWhisper:  65%|██████▌   | 13/20 [01:36<00:52,  7.46s/it]
# IndicWhisper:  70%|███████   | 14/20 [01:46<00:48,  8.10s/it]
# IndicWhisper:  75%|███████▌  | 15/20 [03:48<03:32, 42.45s/it]
# IndicWhisper:  80%|████████  | 16/20 [03:59<02:12, 33.15s/it]
# IndicWhisper:  85%|████████▌ | 17/20 [04:08<01:17, 25.71s/it]
# IndicWhisper:  90%|█████████ | 18/20 [04:13<00:39, 19.65s/it]
# IndicWhisper:  95%|█████████▌| 19/20 [04:21<00:16, 16.21s/it]
# IndicWhisper: 100%|██████████| 20/20 [04:27<00:00, 13.39s/it]
# WER 0.910  CER 0.776  Fuzzy 74.2  EHR 55.0%  Latency 12.77s
#                locality                                       ground_truth  \
# 0           Koramangala         haan bhai main koramangala mein rehta hoon
# 1           Indiranagar  mera ghar indiranagar ke paas hai 100 feet roa...
# 2            Whitefield         sir main whitefield se hoon thoda door hai
# 3       Electronic City  electronic city mein kaam karta hoon phase 2 mein
# 4          Marathahalli           arey marathahalli toh bohot far hai yaar
# 5             Jayanagar           main jayanagar 4th block mein rehta hoon
# 6           Rajajinagar                haan rajajinagar wahan se hoon main
# 7                Hebbal               hebbal flyover ke paas mera ghar hai
# 8             Yelahanka  main yelahanka new town mein shift hua hoon re...
# 9            HSR Layout                hsr layout sector 2 mein rehta hoon
# 10           BTM Layout                     btm layout haan 2nd stage mein
# 11           Silk Board          office silk board junction ke paas hi hai
# 12            Bellandur                 bellandur mein flat liya hai maine
# 13             Sarjapur                    sarjapur road pe rehte hain hum
# 14               Peenya           peenya industrial area mein job hai meri
# 15  Rajarajeshwarinagar  rajarajeshwarinagar mein rehta hoon main rr na...
# 16             KR Puram        kr puram bridge ke paas drop kar dena mujhe
# 17         Banashankari             banashankari temple ke paas rehta hoon
# 18         Yeshwanthpur           yeshwanthpur station ke paas mera pg hai
# 19          Thanisandra                 thanisandra main road pe hoon abhi
#
#                                        hypothesis_raw  \
# 0                हाँ भाई, मैं कुड़मंगला में रहता हूँ।
# 1   मेरा घर इंदिरानगर के पास है, सॉफ्टफिट रोड के ऊपर.
# 2           जब मैं व्हाइट फील्ड से हूँ, थोड़ा दूध है।
# 3     इलेक्ट्रॉनिक सिटी में काम करता हूँ (फ़ेज2) में.
# 4                    अरे माराथली तो बहुत सहार है यार.
# 5                 मैं जयनगर फोर्ट ब्लॉक में रहता हूँ।
# 6                           हाँ, राजनगर, वहाँ से हुए.
# 7                   एब्बाल फ्लाइबर के पास मेरा घर है।
# 8   मैं यह लहंका न्यू टाउन में शिफ्ट हुआ हूँ रीसें...
# 9           एचएस सात लेआउट सेक्टर 2 में रहता हूँ मैं.
# 10                बीटीएम लेआउट. हाँ, सेकंड स्टेज में.
# 11                 ऑफिस सेल्फ बोर्ड जंक्शन के पास है.
# 12                   बेलनदूर में फ्लैट लिया है मैंने.
# 13                         सरजापुर रोड पर रहते हैं हम
# 14  पीनिया इंडस्ट्रियल एरिया में जॉब है मेडी।ूनूनू...
# 15  राजा राजेश्वरी नगर में रहता हूँ मैं (हरा नगर ब...
# 16          शेयरपुरम ब्रिज के पास ट्रॉप कर देना मुझे.
# 17                    बनशंकरी टेम्पल के पास रहता हूँ.
# 18              जैसवंतपुर स्टेशन के पास मेरा पीजी है.
# 19                    खानीशांद्रा मेन रोड पर हूँ अभी.
#
#                                            hypothesis       wer  fuzzy_score  \
# 0       ha.n bhai, maim ku.damamgala mem rahata hu.n|  1.000000    63.636364
# 1   mera ghara imdiranagara ke pasa hai, saॉphtaph...  0.727273    90.909091
# 2   jaba maim vhaita philda se hu.n, tho.da dudha ...  1.000000    50.000000
# 3   ilektraॉnika siti mem kama karata hu.n (feja2)...  1.000000    60.000000
# 4            are marathali to bahuta sahara hai yara.  0.857143    75.000000
# 5      maim jayanagara phorta blaॉka mem rahata hu.n|  1.000000   100.000000
# 6                    ha.n, rajanagara, vaha.n se hue.  0.833333    81.818182
# 7            ebbala phlaibara ke pasa mera ghara hai|  0.714286    90.909091
# 8   maim yaha lahamka nyu tauna mem shiphta hua hu...  1.000000    66.666667
# 9   echaesa sata leauta sektara 2 mem rahata hu.n ...  1.142857    60.000000
# 10           bitiema leauta. ha.n, sekamda steja mem.  1.000000    60.000000
# 11         ऑphisa selpha borda jamkshana ke pasa hai.  0.875000    60.000000
# 12            belanadura mem phlaita liya hai maimne.  0.666667    88.888889
# 13              sarajapura roda para rahate haim hama  1.000000    87.500000
# 14  piniya imdastriyala eriya mem jaॉba hai medi|u...  0.857143    66.666667
# 15  raja rajeshvari nagara mem rahata hu.n maim (h...  1.200000    84.210526
# 16  sheyarapurama brija ke pasa traॉpa kara dena m...  0.777778    75.000000
# 17          banashamkari tempala ke pasa rahata hu.n.  0.833333    91.666667
# 18     jaisavamtapura steshana ke pasa mera piji hai.  0.714286    50.000000
# 19             khanishamdra mena roda para hu.n abhi.  1.000000    81.818182
#
#     entity_hit
# 0            0
# 1            1
# 2            0
# 3            0
# 4            1
# 5            1
# 6            1
# 7            1
# 8            0
# 9            0
# 10           0
# 11           0
# 12           1
# 13           1
# 14           0
# 15           1
# 16           1
# 17           1
# 18           0
# 19           1

# %% [markdown]
# ## 4. Sarvam AI (Saaras v3)

# %%
SARVAM_URL = 'https://api.sarvam.ai/speech-to-text'
import threading
import threading

class RateLimiter:
    """Token bucket — enforces minimum gap between calls."""
    def __init__(self, calls_per_minute=20):
        self._interval = 60.0 / calls_per_minute
        self._last     = 0.0
        self._lock     = threading.Lock()

    def wait(self):
        with self._lock:
            gap = time.time() - self._last
            if gap < self._interval:
                time.sleep(self._interval - gap)
            self._last = time.time()


_sarvam_limiter = RateLimiter(calls_per_minute=15)

def run_sarvam(df, api_key, label='Sarvam AI', base_dir=None):
    headers = {'api-subscription-key': api_key}
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc=label):
        path = os.path.join(base_dir or RECORDINGS_DIR, row['filename'])
        tmp  = None
        raw, lat = '', None
        try:
            audio, sr = load_audio(path)
            tmp = to_wav(audio, sr)
            for attempt in range(5):
                _sarvam_limiter.wait()
                with open(tmp, 'rb') as f:
                    files = {'file': (row['filename'].rsplit('.', 1)[0] + '.wav', f, 'audio/wav')}
                    data  = {'language_code': 'hi-IN', 'model': 'saaras:v3'}
                    t0    = time.time()
                    resp  = requests.post(SARVAM_URL, headers=headers,
                                          files=files, data=data, timeout=30)
                    lat   = time.time() - t0
                if resp.status_code == 429:
                    wait = min(30, 2 ** attempt)
                    print(f'  [{row["filename"]}] 429, retry {attempt+1}/5 in {wait}s')
                    lat = None
                    time.sleep(wait)
                    continue
                resp.raise_for_status()
                raw = resp.json().get('transcript', '')
                break
        except Exception as e:
            print(f'  [{row["filename"]}] {e}')
        finally:
            cleanup(tmp)
        results.append({'filename': row['filename'], 'locality': row['locality'],
                        'ground_truth': row['ground_truth'], 'latency_s': lat,
                        'model': label, **score(row['ground_truth'], row['locality'], raw)})
    return pd.DataFrame(results)




sarvam_df = run_sarvam(gt, SARVAM_KEY)
print(f"WER {sarvam_df['wer'].mean():.3f}  CER {sarvam_df['cer'].mean():.3f}  "
      f"Fuzzy {sarvam_df['fuzzy_score'].mean():.1f}  EHR {sarvam_df['entity_hit'].mean():.1%}  "
      f"Latency {sarvam_df['latency_s'].mean():.2f}s")
sarvam_df[['locality','ground_truth','hypothesis_raw','hypothesis','wer','fuzzy_score','entity_hit']]
# Out:
# Sarvam AI:   0%|          | 0/20 [00:00<?, ?it/s]
# Sarvam AI:   5%|▌         | 1/20 [00:05<01:39,  5.24s/it]
# Sarvam AI:  10%|█         | 2/20 [00:09<01:20,  4.46s/it]
# Sarvam AI:  15%|█▌        | 3/20 [00:13<01:12,  4.25s/it]
# Sarvam AI:  20%|██        | 4/20 [00:17<01:06,  4.15s/it]
# Sarvam AI:  25%|██▌       | 5/20 [00:21<01:01,  4.11s/it]
# Sarvam AI:  30%|███       | 6/20 [00:25<00:58,  4.19s/it]
# Sarvam AI:  35%|███▌      | 7/20 [00:31<01:02,  4.83s/it]
# Sarvam AI:  40%|████      | 8/20 [00:37<01:01,  5.16s/it]
# Sarvam AI:  45%|████▌     | 9/20 [00:41<00:54,  4.92s/it]
# Sarvam AI:  50%|█████     | 10/20 [00:45<00:45,  4.57s/it]
#   [BTM layout.mp3] 429, retry 1/5 in 1s
#   [BTM layout.mp3] 429, retry 2/5 in 2s
#   [BTM layout.mp3] 429, retry 3/5 in 4s
#   [BTM layout.mp3] 429, retry 4/5 in 8s
# Sarvam AI:  55%|█████▌    | 11/20 [01:12<01:40, 11.21s/it]
# Sarvam AI:  60%|██████    | 12/20 [01:16<01:12,  9.08s/it]
#   [Bellandur.mp3] 429, retry 1/5 in 1s
# Sarvam AI:  65%|██████▌   | 13/20 [01:23<01:00,  8.68s/it]
# Sarvam AI:  70%|███████   | 14/20 [01:27<00:43,  7.25s/it]
#   [peenya.mp3] 429, retry 1/5 in 1s
# Sarvam AI:  75%|███████▌  | 15/20 [01:35<00:37,  7.46s/it]
#   [RajarajeshwariNagar.mp3] 429, retry 1/5 in 1s
# Sarvam AI:  80%|████████  | 16/20 [01:44<00:30,  7.71s/it]
# Sarvam AI:  85%|████████▌ | 17/20 [01:48<00:19,  6.55s/it]
#   [banshakari.mp3] 429, retry 1/5 in 1s
# Sarvam AI:  90%|█████████ | 18/20 [01:55<00:13,  6.94s/it]
#   [Yeshwantpur.mp3] 429, retry 1/5 in 1s
# Sarvam AI:  95%|█████████▌| 19/20 [02:03<00:07,  7.28s/it]
# Sarvam AI: 100%|██████████| 20/20 [02:07<00:00,  6.39s/it]
# WER 0.940  CER 0.417  Fuzzy 77.1  EHR 55.0%  Latency 1.29s
#                locality                                       ground_truth  \
# 0           Koramangala         haan bhai main koramangala mein rehta hoon
# 1           Indiranagar  mera ghar indiranagar ke paas hai 100 feet roa...
# 2            Whitefield         sir main whitefield se hoon thoda door hai
# 3       Electronic City  electronic city mein kaam karta hoon phase 2 mein
# 4          Marathahalli           arey marathahalli toh bohot far hai yaar
# 5             Jayanagar           main jayanagar 4th block mein rehta hoon
# 6           Rajajinagar                haan rajajinagar wahan se hoon main
# 7                Hebbal               hebbal flyover ke paas mera ghar hai
# 8             Yelahanka  main yelahanka new town mein shift hua hoon re...
# 9            HSR Layout                hsr layout sector 2 mein rehta hoon
# 10           BTM Layout                     btm layout haan 2nd stage mein
# 11           Silk Board          office silk board junction ke paas hi hai
# 12            Bellandur                 bellandur mein flat liya hai maine
# 13             Sarjapur                    sarjapur road pe rehte hain hum
# 14               Peenya           peenya industrial area mein job hai meri
# 15  Rajarajeshwarinagar  rajarajeshwarinagar mein rehta hoon main rr na...
# 16             KR Puram        kr puram bridge ke paas drop kar dena mujhe
# 17         Banashankari             banashankari temple ke paas rehta hoon
# 18         Yeshwanthpur           yeshwanthpur station ke paas mera pg hai
# 19          Thanisandra                 thanisandra main road pe hoon abhi
#
#                                        hypothesis_raw  \
# 0                 हाँ भाई, मैं कोरमंगला में रहता हूँ।
# 1    मेरा घर इंदिरानगर के पास है, 100 फीट रोड के ऊपर।
# 2            सर, मैं वाइट फील्ड से हूँ, थोड़ा दूर है।
# 3      इलेक्ट्रॉनिक सिटी में काम करता हूँ फेज़ टू में
# 4                    अरे मारा थाली तो बहुत फार है यार
# 5                  मैं जयनगर फोर्थ ब्लॉक में रहता हूँ
# 6                    हाँ, राधाजी नगर वहाँ से हूँ मैं।
# 7                 हेब्बाल फ्लाईओवर के पास मेरा घर है।
# 8   मैं ये लहंगा न्यू टाउन में शिफ्ट हुआ हूँ रिसेंटली
# 9          नीचे सात लेआउट सेक्टर टू में रहता हूँ मैं।
# 10                बीटीएम लेआउट? हाँ, सेकंड स्टेज में।
# 11                 ऑफिस सिल्क बोर्ड जंक्शन के पास है।
# 12                  बेलेनदूर में फ्लैट लिया है मैंने।
# 13                        सरजापुर रोड पर रहते हैं हम।
# 14              पीनिया इंडस्टल एरिया में जॉब है मेरी।
# 15  राजा राजेश्वरी नगर में रहता हूँ मैं, हारा नगर ...
# 16     के आर पुरम ब्रिज के पास ड्रॉप कर देना है मुझे।
# 17                    बनशंकरी टेम्पल के पास रहता हूँ।
# 18                यशवंतपुर स्टेशन के पास मेरा पीजी है
# 19                   रानी सांद्रा मेन रोड पर हूँ अभी।
#
#                                            hypothesis       wer  fuzzy_score  \
# 0        ha.n bhai, maim koramamgala mem rahata hu.n|  1.000000    90.909091
# 1   mera ghara imdiranagara ke pasa hai, 100 phita...  0.636364    90.909091
# 2   sara, maim vaita philda se hu.n, tho.da dura hai|  1.000000    50.000000
# 3   ilektraॉnika siti mem kama karata hu.n pheza t...  1.000000    60.000000
# 4             are mara thali to bahuta phara hai yara  1.000000    75.000000
# 5      maim jayanagara phortha blaॉka mem rahata hu.n  1.000000   100.000000
# 6           ha.n, radhaji nagara vaha.n se hu.n maim|  1.000000    72.727273
# 7          hebbala phlaiovara ke pasa mera ghara hai|  0.714286   100.000000
# 8   maim ye lahamga nyu tauna mem shiphta hua hu.n...  1.000000    66.666667
# 9   niche sata leauta sektara tu mem rahata hu.n m...  1.285714    60.000000
# 10           bitiema leauta? ha.n, sekamda steja mem|  1.000000    60.000000
# 11          ऑphisa silka borda jamkshana ke pasa hai|  0.875000    90.000000
# 12            belenadura mem phlaita liya hai maimne|  0.666667    77.777778
# 13             sarajapura roda para rahate haim hama|  1.000000    87.500000
# 14         piniya imdastala eriya mem jaॉba hai meri|  0.857143    66.666667
# 15  raja rajeshvari nagara mem rahata hu.n maim, h...  1.200000    84.210526
# 16  ke ara purama brija ke pasa draॉpa kara dena h...  1.000000    87.500000
# 17          banashamkari tempala ke pasa rahata hu.n|  0.833333    91.666667
# 18      yashavamtapura steshana ke pasa mera piji hai  0.571429    58.333333
# 19              rani samdra mena roda para hu.n abhi|  1.166667    72.727273
#
#     entity_hit
# 0            1
# 1            1
# 2            0
# 3            0
# 4            1
# 5            1
# 6            0
# 7            1
# 8            0
# 9            0
# 10           0
# 11           1
# 12           1
# 13           1
# 14           0
# 15           1
# 16           1
# 17           1
# 18           0
# 19           0

# %% [markdown]
# ## 5. FLEURS Hindi — Out-of-domain Evaluation
# Google FLEURS `hi_in` test split, 30 samples. 50% augmented with Gaussian noise (seed=42).

# %%
from datasets import load_dataset
from audiomentations import Compose, AddGaussianNoise

random.seed(42)
np.random.seed(42)

augmentor = Compose([AddGaussianNoise(min_amplitude=0.005, max_amplitude=0.04, p=1.0)])

stream = load_dataset('google/fleurs', 'hi_in', split='test', streaming=True)

fleurs_rows = []
for i, s in enumerate(stream):
    if i >= 30:
        break
    audio = librosa.resample(s['audio']['array'].astype(np.float32),
                             orig_sr=s['audio']['sampling_rate'], target_sr=16000)
    noisy = random.random() < 0.5
    if noisy:
        audio = augmentor(samples=audio, sample_rate=16000)

    fname = f"fleurs_{i:02d}_{'noisy' if noisy else 'clean'}.wav"
    sf.write(os.path.join(TEMP_DIR, fname), audio, 16000)
    fleurs_rows.append({
        'filename':     fname,
        'ground_truth': s['transcription'].strip().lower(),
        'locality':     'N/A',
        'noisy':        noisy,
    })

gt_fleurs = pd.DataFrame(fleurs_rows)
print(f"{len(gt_fleurs)} samples — {gt_fleurs['noisy'].sum()} noisy, {(~gt_fleurs['noisy']).sum()} clean")
# Out:
# README.md:   0%|          | 0.00/386k [00:00<?, ?B/s]
# 30 samples — 11 noisy, 19 clean

# %%
fleurs_deepgram_df = run_deepgram(gt_fleurs,     DEEPGRAM_KEY,  base_dir=TEMP_DIR)
fleurs_whisper_df  = run_whisper(gt_fleurs,      whisper_model, base_dir=TEMP_DIR)
fleurs_indic_df    = run_indicwhisper(gt_fleurs, indic_pipe,    base_dir=TEMP_DIR)
fleurs_sarvam_df   = run_sarvam(gt_fleurs,       SARVAM_KEY,    base_dir=TEMP_DIR)

fleurs_all_df = pd.concat(
    [fleurs_deepgram_df, fleurs_whisper_df, fleurs_indic_df, fleurs_sarvam_df],
    ignore_index=True,
)
fleurs_all_df['noisy'] = fleurs_all_df['filename'].str.contains('noisy')

print(f"FLEURS eval done — {len(fleurs_all_df)} rows")
# Out:
# Deepgram:   0%|          | 0/30 [00:00<?, ?it/s]
# Deepgram:   3%|▎         | 1/30 [00:03<01:43,  3.56s/it]
# Deepgram:   7%|▋         | 2/30 [00:05<01:11,  2.55s/it]
# Deepgram:  10%|█         | 3/30 [00:06<00:56,  2.10s/it]
# Deepgram:  13%|█▎        | 4/30 [00:08<00:47,  1.83s/it]
# Deepgram:  17%|█▋        | 5/30 [00:09<00:40,  1.61s/it]
# Deepgram:  20%|██        | 6/30 [00:10<00:35,  1.49s/it]
# Deepgram:  23%|██▎       | 7/30 [00:12<00:36,  1.60s/it]
# Deepgram:  27%|██▋       | 8/30 [00:14<00:36,  1.64s/it]
# Deepgram:  30%|███       | 9/30 [00:15<00:33,  1.58s/it]
# Deepgram:  33%|███▎      | 10/30 [00:17<00:35,  1.75s/it]
# Deepgram:  37%|███▋      | 11/30 [00:19<00:32,  1.71s/it]
# Deepgram:  40%|████      | 12/30 [00:21<00:31,  1.76s/it]
# Deepgram:  43%|████▎     | 13/30 [00:22<00:27,  1.59s/it]
# Deepgram:  47%|████▋     | 14/30 [00:24<00:24,  1.52s/it]
# Deepgram:  50%|█████     | 15/30 [00:25<00:22,  1.49s/it]
# Deepgram:  53%|█████▎    | 16/30 [00:26<00:20,  1.44s/it]
# Deepgram:  57%|█████▋    | 17/30 [00:27<00:17,  1.37s/it]
# Deepgram:  60%|██████    | 18/30 [00:29<00:16,  1.37s/it]
# Deepgram:  63%|██████▎   | 19/30 [00:30<00:14,  1.27s/it]
# Deepgram:  67%|██████▋   | 20/30 [00:31<00:12,  1.25s/it]
# Deepgram:  70%|███████   | 21/30 [00:33<00:13,  1.53s/it]
# Deepgram:  73%|███████▎  | 22/30 [00:35<00:11,  1.46s/it]
# Deepgram:  77%|███████▋  | 23/30 [00:36<00:09,  1.35s/it]
# Deepgram:  80%|████████  | 24/30 [00:37<00:07,  1.32s/it]
# Deepgram:  83%|████████▎ | 25/30 [00:38<00:06,  1.32s/it]
# Deepgram:  87%|████████▋ | 26/30 [00:39<00:04,  1.22s/it]
# Deepgram:  90%|█████████ | 27/30 [00:41<00:03,  1.31s/it]
# Deepgram:  93%|█████████▎| 28/30 [00:42<00:02,  1.44s/it]
# Deepgram:  97%|█████████▋| 29/30 [00:44<00:01,  1.52s/it]
# Deepgram: 100%|██████████| 30/30 [00:46<00:00,  1.53s/it]
# Whisper Medium: 100%|██████████| 30/30 [02:52<00:00,  5.73s/it]
# IndicWhisper: 100%|██████████| 30/30 [12:47<00:00, 25.59s/it]
# Sarvam AI:  37%|███▋      | 11/30 [00:41<01:16,  4.04s/it]
#   [fleurs_11_noisy.wav] 429, retry 1/5 in 1s
#   [fleurs_11_noisy.wav] 429, retry 2/5 in 2s
#   [fleurs_11_noisy.wav] 429, retry 3/5 in 4s
#   [fleurs_11_noisy.wav] 429, retry 4/5 in 8s
#   [fleurs_11_noisy.wav] 429, retry 5/5 in 16s
# Sarvam AI:  60%|██████    | 18/30 [01:45<01:03,  5.27s/it]
#   [fleurs_18_clean.wav] 429, retry 1/5 in 1s
# Sarvam AI:  67%|██████▋   | 20/30 [01:57<00:54,  5.46s/it]
#   [fleurs_20_noisy.wav] 429, retry 1/5 in 1s
# Sarvam AI:  70%|███████   | 21/30 [02:05<00:56,  6.29s/it]
#   [fleurs_21_noisy.wav] 429, retry 1/5 in 1s
# Sarvam AI:  77%|███████▋  | 23/30 [02:17<00:40,  5.85s/it]
#   [fleurs_23_clean.wav] 429, retry 1/5 in 1s
# Sarvam AI:  83%|████████▎ | 25/30 [02:29<00:28,  5.79s/it]
#   [fleurs_25_clean.wav] 429, retry 1/5 in 1s
# Sarvam AI:  87%|████████▋ | 26/30 [02:37<00:25,  6.40s/it]
#   [fleurs_26_noisy.wav] 429, retry 1/5 in 1s
# Sarvam AI:  90%|█████████ | 27/30 [02:45<00:20,  6.79s/it]
#   [fleurs_27_clean.wav] 429, retry 1/5 in 1s
# Sarvam AI:  97%|█████████▋| 29/30 [02:57<00:06,  6.41s/it]
#   [fleurs_29_clean.wav] 429, retry 1/5 in 1s
# Sarvam AI: 100%|██████████| 30/30 [03:05<00:00,  6.18s/it]
# FLEURS eval done — 120 rows

# %% [markdown]
# ## Results

# %%
own_df = pd.concat([deepgram_df, whisper_df, indic_df, sarvam_df], ignore_index=True)

summary = own_df.groupby('model').agg(
    WER=('wer', 'mean'), CER=('cer', 'mean'),
    Fuzzy=('fuzzy_score', 'mean'), EHR=('entity_hit', 'mean'),
    Latency=('latency_s', 'mean')
).round(3).reset_index().sort_values('WER')

summary['EHR'] = summary['EHR'].map('{:.1%}'.format)
print(summary.to_string(index=False))
# Out:
#           model   WER   CER  Fuzzy   EHR  Latency
# Deepgram Nova-2 0.831 0.399 69.479 55.0%    1.649
#  Whisper Medium 0.861 0.410 77.090 60.0%    2.063
#    IndicWhisper 0.910 0.776 74.235 55.0%   12.774
#       Sarvam AI 0.940 0.417 77.130 55.0%    1.295

# %%
fleurs_summary = (
    fleurs_all_df.groupby(['model', 'noisy'])['wer']
    .mean().round(3).unstack()
    .rename(columns={False: 'WER_clean', True: 'WER_noisy'})
)
fleurs_summary['degradation'] = (fleurs_summary['WER_noisy'] - fleurs_summary['WER_clean']).round(3)
print(fleurs_summary.to_string())
# Out:
# noisy            WER_clean  WER_noisy  degradation
# model
# Deepgram Nova-2      1.011      1.041        0.030
# IndicWhisper         0.997      1.023        0.026
# Sarvam AI            1.007      1.045        0.038
# Whisper Medium       1.026      1.032        0.006

# %% [markdown]
# ## Visualizations

# %%
MODELS  = ['Deepgram Nova-2', 'Whisper Medium', 'IndicWhisper', 'Sarvam AI']
COLORS  = ['#5C6BC0', '#26A69A', '#FFA726', '#EF5350']
cmap    = dict(zip(MODELS, COLORS))

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('ASR Benchmark — Own Recordings (20 samples, Hinglish)', fontsize=13)

def bar(ax, data, title, ylabel, fmt='{:.2f}', ylim=None):
    bars = ax.bar(data.index, data.values, color=[cmap.get(m, '#999') for m in data.index], width=0.5)
    ax.set_title(title); ax.set_ylabel(ylabel)
    ax.set_xticklabels(data.index, rotation=15, ha='right', fontsize=9)
    if ylim: ax.set_ylim(*ylim)
    for b, v in zip(bars, data.values):
        ax.text(b.get_x() + b.get_width()/2, v + max(data.values)*0.02,
                fmt.format(v), ha='center', fontsize=9)

bar(axes[0,0], own_df.groupby('model')['wer'].mean().reindex(MODELS),
    'Word Error Rate (lower is better)', 'WER')

ehr = own_df.groupby('model')['entity_hit'].mean().reindex(MODELS) * 100
bar(axes[0,1], ehr, 'Entity Hit Rate (locality captured?)', '%',
    fmt='{:.0f}%', ylim=(0, 115))
axes[0,1].axhline(y=75, color='gray', linestyle='--', linewidth=0.8, label='75% threshold')

bar(axes[1,0], own_df.groupby('model')['fuzzy_score'].mean().reindex(MODELS),
    'Mean Fuzzy Score — partial_ratio (0-100)', 'Score', fmt='{:.1f}', ylim=(0, 110))
axes[1,0].axhline(y=75, color='gray', linestyle='--', linewidth=0.8)

bar(axes[1,1], own_df.groupby('model')['latency_s'].mean().reindex(MODELS),
    'Mean Latency per Sample', 's', fmt='{:.2f}s')

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/asr/benchmark_results.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
x     = np.arange(len(MODELS))
w     = 0.35
clean = [fleurs_summary.loc[m, 'WER_clean'] for m in MODELS]
noisy = [fleurs_summary.loc[m, 'WER_noisy'] for m in MODELS]

fig, ax = plt.subplots(figsize=(9, 5))
ax.bar(x - w/2, clean, w, label='Clean', color='#66BB6A')
ax.bar(x + w/2, noisy, w, label='Noisy', color='#EF5350')
ax.set_title('FLEURS Hindi WER — Clean vs Noise-augmented')
ax.set_ylabel('WER'); ax.set_xticks(x); ax.set_xticklabels(MODELS, rotation=12, ha='right')
ax.legend()
for i, (c, n) in enumerate(zip(clean, noisy)):
    ax.text(i - w/2, c + 0.01, f'{c:.2f}', ha='center', fontsize=8)
    ax.text(i + w/2, n + 0.01, f'{n:.2f}', ha='center', fontsize=8)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/asr/fleurs_results.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

pivot_ehr = own_df.pivot_table(index='locality', columns='model',
                                values='entity_hit', aggfunc='mean').fillna(0)
sns.heatmap(pivot_ehr, annot=True, fmt='.0%', cmap='RdYlGn',
            linewidths=0.4, vmin=0, vmax=1, ax=ax1)
ax1.set_title('Entity Hit Rate by Locality x Model')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha='right')

pivot_fuz = own_df.pivot_table(index='locality', columns='model',
                                values='fuzzy_score', aggfunc='mean').fillna(0)
sns.heatmap(pivot_fuz, annot=True, fmt='.0f', cmap='RdYlGn',
            linewidths=0.4, vmin=0, vmax=100, ax=ax2)
ax2.set_title('Fuzzy Score by Locality x Model')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=15, ha='right')

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/asr/heatmaps.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Failure Analysis

# %%
print('Hardest localities (avg EHR across models):')
print(own_df.groupby('locality')['entity_hit'].mean().sort_values().round(2).to_string())

print('\nConsistently missed (entity_hit=0 in all models):')
miss_counts = own_df.groupby('locality')['entity_hit'].sum()
print(miss_counts[miss_counts == 0].index.tolist())

print('\nWorst individual predictions:')
failures = own_df[own_df['entity_hit'] == 0][
    ['model','locality','hypothesis_raw','fuzzy_score','wer']
].sort_values('fuzzy_score').head(12)
print(failures.to_string(index=False))

print('\nModel consistency (WER std):')
print(own_df.groupby('model')['wer'].agg(['mean','std','min','max']).round(3).to_string())
# Out:
# Hardest localities (avg EHR across models):
# locality
# Peenya                 0.00
# Yeshwanthpur           0.00
# HSR Layout             0.25
# Electronic City        0.25
# Whitefield             0.25
# Yelahanka              0.25
# Indiranagar            0.50
# Hebbal                 0.50
# Thanisandra            0.50
# Rajajinagar            0.50
# Koramangala            0.50
# BTM Layout             0.50
# Silk Board             0.75
# Rajarajeshwarinagar    0.75
# Bellandur              0.75
# Banashankari           1.00
# Sarjapur               1.00
# Marathahalli           1.00
# KR Puram               1.00
# Jayanagar              1.00
#
# Consistently missed (entity_hit=0 in all models):
# ['Peenya', 'Yeshwanthpur']
#
# Worst individual predictions:
#           model     locality                             hypothesis_raw  fuzzy_score      wer
# Deepgram Nova-2  Indiranagar                                                0.000000 1.000000
#  Whisper Medium   Whitefield        सदमा वाय फेल से हूं थोले दो रहे हैं    35.294118 1.000000
# Deepgram Nova-2 Yeshwanthpur    जैसलमेरपुर station के पास मेरा busy है.    41.666667 0.571429
# Deepgram Nova-2   HSR Layout पीछे साथ लिया और sector 2 में रहता हूं मैं    50.000000 1.142857
#    IndicWhisper Yeshwanthpur      जैसवंतपुर स्टेशन के पास मेरा पीजी है.    50.000000 0.714286
#       Sarvam AI   Whitefield   सर, मैं वाइट फील्ड से हूँ, थोड़ा दूर है।    50.000000 1.000000
#    IndicWhisper   Whitefield  जब मैं व्हाइट फील्ड से हूँ, थोड़ा दूध है।    50.000000 1.000000
# Deepgram Nova-2  Thanisandra                      Main road पर हूं अभी.    52.631579 0.666667
#  Whisper Medium  Koramangala          हा बही मैं कुर्मंग्रा में रहा हूँ    54.545455 1.000000
# Deepgram Nova-2  Rajajinagar                 हां, नगर. वहां से हूं मैं.    57.142857 0.833333
#       Sarvam AI Yeshwanthpur        यशवंतपुर स्टेशन के पास मेरा पीजी है    58.333333 0.571429
#    IndicWhisper   HSR Layout  एचएस सात लेआउट सेक्टर 2 में रहता हूँ मैं.    60.000000 1.142857
#
# Model consistency (WER std):
#                   mean    std    min    max
# model
# Deepgram Nova-2  0.831  0.193  0.429  1.200
# IndicWhisper     0.910  0.147  0.667  1.200
# Sarvam AI        0.940  0.185  0.571  1.286
# Whisper Medium   0.861  0.213  0.250  1.200

# %%
import nbformat, json

path = '/content/drive/MyDrive/asr/asr_final.ipynb'  # adjust if different
nb = nbformat.read(open(path), as_version=4)

# Fix the widgets metadata
if 'widgets' in nb.metadata:
    del nb.metadata['widgets']

nbformat.write(nb, open(path, 'w'))
print('Fixed')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7524/3073412740.py in <cell line: 0>()
#       2
#       3 path = '/content/drive/MyDrive/asr/asr_final.ipynb'  # adjust if different
# ----> 4 nb = nbformat.read(open(path), as_version=4)
#       5
#       6 # Fix the widgets metadata
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/asr/asr_final.ipynb'
